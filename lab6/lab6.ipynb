# %%
# Вариант 15
# Функция: z = x * sin(y)  
# Ограничения: x(-p<=x<=p) y(-p<=y<=p) z(-3<=z<=3)

# %%
import matplotlib.pyplot as plt

# %%
GEN_5 = [1.9738324542203, 1.7438399269046074, 1.4592111969599648, 1.6505262263896323, 1.8204238576038638]

GEN_7 = [1.1788666874022127, 1.2047404383557163, 1.4226453394661516, 1.0770126452810282, 1.1640188592810277]

GEN_9 = [1.1325503504464145, 1.1214105040164901, 1.2054944275337047, 1.145610770304224, 0.9371618303667176]

fix, ax = plt.subplots()
ax.set_title('Генетический аглоритм с разным количеством термов')
ax.plot([5, 5, 5, 5, 5], GEN_5, '+', label='5 термов')
ax.plot([7, 7, 7, 7, 7], GEN_7, '+', label='7 термов')
ax.plot([9, 9, 9, 9, 9], GEN_9, '+', label='9 термов')
plt.legend()

# %%
ANT_5 = [0.3269873305575228, 0.37392431812079197, 0.41559364410330407, 0.41559364410330407, 0.3269873305575228]

ANT_7 = [0.21799155370501552, 0.24928287874719499, 0.24928287874719499, 0.21799155370501552, 0.26353893775184295]

ANT_9 = [0.1634936652787614, 0.18696215906039598, 0.1634936652787614, 0.1634936652787614, 0.20779682205165204]

fix,ax = plt.subplots()
ax.set_title('Муравьиный алгоритм с разным количеством термов')
ax.plot([5, 5, 5, 5, 5], ANT_5, '+', label='5 термов')
ax.plot([7, 7, 7, 7, 7], ANT_7, '+', label='7 термов')
ax.plot([9, 9, 9, 9, 9], ANT_9, '+', label='9 термов')
plt.legend()

# %%
GEN_POPULATION_10 = [1.1325503504464145, 1.1214105040164901, 1.2054944275337047, 1.145610770304224, 0.9371618303667176]

GEN_POPULATION_50 = [1.0662256206235499, 1.164632655485077, 1.1544640731942661, 1.1535617307568184, 1.0707767343451269]

GEN_POPULATION_100 = [1.0607671228355868, 1.1310443879032366, 1.0152179842553792, 1.207260305172188, 1.1197736047638942]

fig, ax = plt.subplots()
ax.set_title('Генетический алгоритм с разными значениями популяции')
ax.plot([10, 10, 10, 10, 10], GEN_POPULATION_10, '+', label='10 особей')
ax.plot([50, 50, 50, 50, 50], GEN_POPULATION_50, '+', label='50 особей')
ax.plot([100, 100, 100, 100, 100], GEN_POPULATION_100, '+', label='100 особей')
ax.legend()

# %%
ANT_POPULATION_10 = [0.18696215906039598, 0.1634936652787614, 0.1634936652787614, 0.1634936652787614, 0.19765420331388192]

ANT_POPULATION_50 = [0.18696215906039598, 0.20779682205165204, 0.1634936652787614, 0.19765420331388192, 0.18696215906039598]

ANT_POPULATION_100 = [0.18696215906039598, 0.18696215906039598, 0.20779682205165204, 0.18696215906039598, 0.19765420331388192]

fig, ax = plt.subplots()
ax.set_title('Муравьиный алгоритм c разными значениями популяции')
ax.plot([10, 10, 10, 10, 10], ANT_POPULATION_10, '+', label='10')
ax.plot([50, 50, 50, 50, 50], ANT_POPULATION_50, '+', label='50')
ax.plot([100, 100, 100, 100, 100], ANT_POPULATION_100, '+', label='100')

# %%
GEN_MUTATION_1 = [1.1172361068809575, 1.0580446150363452, 1.0256379225380408, 1.2566129372539796, 1.0899798503064515]

GEN_MUTATION_2 = [1.2367564507689128, 1.1745839452522941, 1.1834139878616725, 1.1311532626941867, 1.1256598229647519]

GEN_MUTATION_3 = [1.2425108688696689, 1.1901646478067178, 1.2465800772067912, 1.0285363026777061, 0.9985469072236547]

fig, ax = plt.subplots()
ax.set_title('Генетический алгоритм с разными значениями количества элементов мутации')
ax.plot([1, 1, 1, 1, 1], GEN_MUTATION_1, '+', label='1 элемента')
ax.plot([2, 2, 2, 2, 2], GEN_MUTATION_2, '+', label='2 элемента')
ax.plot([3, 3, 3, 3, 3], GEN_MUTATION_3, '+', label='3 элемента')
ax.legend()

# %%
ANT_ALPHA_0DOT5 = [0.1634936652787614, 0.18696215906039598, 0.1634936652787614, 0.1634936652787614, 0.20779682205165204]

ANT_ALPHA_1 = [0.1634936652787614, 0.19765420331388192, 0.18696215906039598, 0.1634936652787614, 0.19765420331388192]

ANT_ALPHA_1DOT5 = [0.18696215906039598, 0.1634936652787614, 0.1634936652787614, 0.1634936652787614, 0.19765420331388192]

fig, ax = plt.subplots()
ax.set_title('Муравьиный алгоритм с разными значениями коэффициента снижения интенсивности фермента')
ax.plot([0.5, 0.5, 0.5, 0.5, 0.5], ANT_ALPHA_0DOT5, '+', label='0.5')
ax.plot([1, 1, 1, 1, 1], ANT_ALPHA_1, '+', label='1')
ax.plot([1.5, 1.5, 1.5, 1.5, 1.5], ANT_ALPHA_1DOT5, '+', label='1.5')
