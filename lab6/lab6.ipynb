# %%
# Вариант 15
# Функция: z = x * sin(y)  
# Ограничения: x(-p<=x<=p) y(-p<=y<=p) z(-3<=z<=3)

# %%
import matplotlib.pyplot as plt

# %%
GEN_5 = [1.8085032301141553, 1.5658994646315367, 1.3820132416152893, 1.5320904673027633, 1.3714547264371022]

GEN_7 = [1.0646019153163486, 1.2701141493507393, 1.3239340006568447, 1.4106120589844613, 1.3952777842559148]

GEN_9 = [1.4127373088099935, 1.4046124152366861, 1.321206883735333, 1.3174301864980535, 1.3357082876248203]

fix, ax = plt.subplots()
ax.set_title('Генетический аглоритм с разным количеством термов')
ax.plot([5, 5, 5, 5, 5], GEN_5, '+', label='5 термов')
ax.plot([7, 7, 7, 7, 7], GEN_7, '+', label='7 термов')
ax.plot([9, 9, 9, 9, 9], GEN_9, '+', label='9 термов')
plt.legend()

# %%
ANT_5 = [0.3269873305575228, 0.41559364410330407, 0.37392431812079197, 0.41559364410330407, 0.3269873305575228 ]

ANT_7 = [0.21799155370501552, 0.26353893775184295, 0.2770624294022031, 0.24928287874719499, 0.2770624294022031]

ANT_9 = [0.1634936652787614, 0.20779682205165204, 0.1634936652787614, 0.1634936652787614, 0.1634936652787614]

fix,ax = plt.subplots()
ax.set_title('Муравьиный алгоритм с разным количеством термов')
ax.plot([5, 5, 5, 5, 5], ANT_5, '+', label='5 термов')
ax.plot([7, 7, 7, 7, 7], ANT_7, '+', label='7 термов')
ax.plot([9, 9, 9, 9, 9], ANT_9, '+', label='9 термов')
plt.legend()

# %%
GEN_POPULATION_10 = [1.5658994646315367, 1.3820132416152893, 1.5320904673027633, 1.3714547264371022, 1.4828677846209573]

GEN_POPULATION_20 = [1.6089223101194166, 1.277772906270907, 1.6209655147473063, 1.705961175798949, 1.292706643700212]

GEN_POPULATION_30 = [1.3525536588246694, 1.6190771445487087, 1.3019176625270892, 1.4828677846209573, 1.2920822471241271]

print(len(GEN_POPULATION_10))
fig, ax = plt.subplots()
ax.set_title('Генетический алгоритм с разными значениями популяции')
ax.plot([10, 10, 10, 10, 10], GEN_POPULATION_10, '+', label='10 особей')
ax.plot([20, 20, 20, 20, 20], GEN_POPULATION_20, '+', label='20 особей')
ax.plot([30, 30, 30, 30, 30], GEN_POPULATION_30, '+', label='30 особей')
ax.legend()
# Out:
# 5

# %%
GEN_MUTATION_1 = [1.2516256983974439, 0.9603506111292356, 1.1387137317881797, 1.002448022112387, 1.000533450307977]

GEN_MUTATION_2 = [1.3525536588246694, 1.6190771445487087, 1.3019176625270892, 1.4828677846209573, 1.2920822471241271]

GEN_MUTATION_3 = [1.5477732392052783, 1.464279253876573, 1.3181253860438822, 1.5072656478979853, 1.4574912464002427]

fig, ax = plt.subplots()
ax.set_title('Генетический алгоритм с разными значениями количества элементов мутации')
ax.plot([1, 1, 1, 1, 1], GEN_MUTATION_1, '+', label='1 элемента')
ax.plot([2, 2, 2, 2, 2], GEN_MUTATION_2, '+', label='2 элемента')
ax.plot([3, 3, 3, 3, 3], GEN_MUTATION_3, '+', label='3 элемента')
ax.legend()

# %%
ANT_ALPHA_0DOT5 = [0.1634936652787614, 0.20779682205165204, 0.1634936652787614, 0.1634936652787614, 0.1634936652787614]

ANT_ALPHA_1 = [0.20779682205165204, 0.19765420331388192, 0.19765420331388192, 0.1634936652787614, 0.18696215906039598]

ANT_ALPHA_1DOT5 = [0.1634936652787614, 0.1634936652787614, 0.18696215906039598, 0.19765420331388192, 0.19765420331388192]

fig, ax = plt.subplots()
ax.set_title('Муравьиный алгоритм с разными значениями коэффициента снижения интенсивности фермента')
ax.plot([0.5, 0.5, 0.5, 0.5, 0.5], ANT_ALPHA_0DOT5, '+', label='0.5')
ax.plot([1, 1, 1, 1, 1], ANT_ALPHA_1, '+', label='1')
ax.plot([1.5, 1.5, 1.5, 1.5, 1.5], ANT_ALPHA_1DOT5, '+', label='1.5')

# %%
ANT_POPULATION_10 = [0.1634936652787614, 0.1634936652787614, 0.18696215906039598, 0.19765420331388192, 0.19765420331388192]

ANT_POPULATION_50 = [0.1634936652787614, 0.20779682205165204, 0.18696215906039598, 0.20779682205165204, 0.18696215906039598 ]

ANT_POPULATION_100 = [0.1634936652787614, 0.1634936652787614, 0.1634936652787614, 0.20779682205165204, 0.1634936652787614]

fig, ax = plt.subplots()
ax.set_title('Муравьиный алгоритм c разными значениями популяции')
ax.plot([10, 10, 10, 10, 10], ANT_POPULATION_10, '+', label='10')
ax.plot([50, 50, 50, 50, 50], ANT_POPULATION_50, '+', label='50')
ax.plot([100, 100, 100, 100, 100], ANT_POPULATION_100, '+', label='100')
